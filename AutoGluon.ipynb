# %% [markdown]
# ## AutoGluon
# - AutoML의 SOTA라 불리는 autogluon을 이용한 모델 핸들링

# %%
# autogluon
# tabular : 표 데이터 
from autogluon.tabular import TabularDataset, TabularPredictor



# cross validation
from sklearn.model_selection import cross_val_predict

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn.metrics import PredictionErrorDisplay
import seaborn as sns

import pandas as pd 
import numpy as np

# 평가 지표
import evaluation

# 모델 저장
import pickle
import joblib

# %%
df = pd.read_csv('dataframes/mice_selected_df.csv')
df = df.loc[:, (df.columns != 'date') & (df.columns != 'previous interest rate') & (df.columns != 'next interest rate') & (df.columns != 'previous change')
                  & (df.columns != 'CPI')& (df.columns != 'corePCE')& (df.columns != 'PPI')& (df.columns != 'industrial production')]
dataset = TabularDataset(df)
regressor = TabularPredictor(label='present change', problem_type = 'regression', eval_metric='rmse')
regressor.fit(train_data=dataset, presets='best_quality', auto_stack=True, fit_weighted_ensemble=True, num_bag_sets=20, refit_full=True,set_best_to_refit_full=True, verbosity=2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20241018_061124"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.10
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          16
# Memory Avail:       19.49 GB / 31.81 GB (61.3%)
# Disk Space Avail:   381.19 GB / 465.13 GB (82.0%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 		Context path: "AutogluonModels\ag-20241018_061124\ds_sub_fit\sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                                model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         ExtraTrees_r49_BAG_L1_FULL      -0.235477  -0.470774  root_mean_squared_error        0.064969       0.064330   0.399433                 0.064969                0.064330           0.399433            1       True         54
# 1            XGBoost_r98_BAG_L1_FULL      -0.237231  -0.455432  root_mean_squared_error        0.040431            NaN   0.612581                 0.040431                     NaN           0.612581            1       True         47
# 2             LightGBMXT_BAG_L1_FULL      -0.237285  -0.490775  root_mean_squared_error        0.008976            NaN   0.094607                 0.008976                     NaN           0.094607            1       True          3
# 3         ExtraTrees_r42_BAG_L1_FULL      -0.239576  -0.465259  root_mean_squared_error        0.065825       0.065801   0.335763                 0.065825                0.065801           0.335763            1       True         20
# 4          LightGBM_r131_BAG_L1_FULL      -0.239695  -0.487568  root_mean_squared_error        0.021941            NaN   0.183829                 0.021941                     NaN           0.183829            1       True         14
# 5          LightGBM_r143_BAG_L1_FULL      -0.240373  -0.496300  root_mean_squared_error        0.007978            NaN   0.120187                 0.007978                     NaN           0.120187            1       True         55
# 6          LightGBM_r196_BAG_L1_FULL      -0.240926  -0.483438  root_mean_squared_error        0.029920            NaN   0.494307                 0.029920                     NaN           0.494307            1       True         42
# 7     NeuralNetTorch_r86_BAG_L1_FULL      -0.241847  -0.465204  root_mean_squared_error        0.014961            NaN   3.118114                 0.014961                     NaN           3.118114            1       True         30
# 8        ExtraTrees_r172_BAG_L1_FULL      -0.241882  -0.498825  root_mean_squared_error        0.056887       0.059836   0.329348                 0.056887                0.059836           0.329348            1       True         34
# 9               LightGBM_BAG_L1_FULL      -0.243603  -0.494911  root_mean_squared_error        0.008977            NaN   0.072315                 0.008977                     NaN           0.072315            1       True          4
# 10         ExtraTreesMSE_BAG_L1_FULL      -0.243707  -0.475605  root_mean_squared_error        0.056044       0.064844   0.322964                 0.056044                0.064844           0.322964            1       True          7
# 11     RandomForest_r195_BAG_L1_FULL      -0.243894  -0.471027  root_mean_squared_error        0.063337       0.065859   0.474099                 0.063337                0.065859           0.474099            1       True         24
# 12           CatBoost_r9_BAG_L2_FULL      -0.244659  -0.442975  root_mean_squared_error        1.652451            NaN  75.039284                 0.022967                     NaN           3.583431            2       True         77
# 13      RandomForest_r39_BAG_L1_FULL      -0.245548  -0.464065  root_mean_squared_error        0.058842       0.065528   0.430035                 0.058842                0.065528           0.430035            1       True         43
# 14          CatBoost_r13_BAG_L2_FULL      -0.246629  -0.452451  root_mean_squared_error        1.649430            NaN  77.493045                 0.019947                     NaN           6.037192            2       True         84
# 15         ExtraTreesMSE_BAG_L2_FULL      -0.248626  -0.442859  root_mean_squared_error        1.685334            NaN  71.851079                 0.055851                0.068825           0.395226            2       True         68
# 16        ExtraTrees_r42_BAG_L2_FULL      -0.248671  -0.441570  root_mean_squared_error        1.703266            NaN  71.838049                 0.073783                0.070816           0.382197            2       True         81
# 17         CatBoost_r177_BAG_L2_FULL      -0.250107  -0.442621  root_mean_squared_error        1.649441            NaN  72.151426                 0.019958                     NaN           0.695574            2       True         73
# 18       RandomForestMSE_BAG_L1_FULL      -0.251071  -0.469599  root_mean_squared_error        0.068815       0.101727   0.613085                 0.068815                0.101727           0.613085            1       True          5
# 19  NeuralNetFastAI_r156_BAG_L1_FULL      -0.251102  -0.476312  root_mean_squared_error        0.029920            NaN   1.983230                 0.029920                     NaN           1.983230            1       True         41
# 20   NeuralNetTorch_r197_BAG_L1_FULL      -0.251669  -0.478523  root_mean_squared_error        0.015985            NaN   1.399009                 0.015985                     NaN           1.399009            1       True         52
# 21        NeuralNetTorch_BAG_L1_FULL      -0.252255  -0.484313  root_mean_squared_error        0.014467            NaN   2.856906                 0.014467                     NaN           2.856906            1       True         10
# 22           XGBoost_r33_BAG_L1_FULL      -0.252779  -0.461746  root_mean_squared_error        0.024933            NaN   0.307793                 0.024933                     NaN           0.307793            1       True         19
# 23         LightGBM_r188_BAG_L1_FULL      -0.253272  -0.472017  root_mean_squared_error        0.014960            NaN   0.223523                 0.014960                     NaN           0.223523            1       True         25
# 24     RandomForest_r127_BAG_L1_FULL      -0.253573  -0.501144  root_mean_squared_error        0.057931       0.062834   0.599462                 0.057931                0.062834           0.599462            1       True         56
# 25              CatBoost_BAG_L2_FULL      -0.253665  -0.441254  root_mean_squared_error        1.649430            NaN  72.723511                 0.019947                     NaN           1.267659            2       True         67
# 26          XGBoost_r194_BAG_L1_FULL      -0.254935  -0.460444  root_mean_squared_error        0.018950            NaN   0.033909                 0.018950                     NaN           0.033909            1       True         33
# 27          LightGBM_r96_BAG_L1_FULL      -0.254962  -0.494518  root_mean_squared_error        0.013963            NaN   0.192488                 0.013963                     NaN           0.192488            1       True         17
# 28           CatBoost_r9_BAG_L1_FULL      -0.254968  -0.443335  root_mean_squared_error        0.012965            NaN   1.630570                 0.012965                     NaN           1.630570            1       True         16
# 29          CatBoost_r50_BAG_L1_FULL      -0.255941  -0.438811  root_mean_squared_error        0.011968            NaN   0.366798                 0.011968                     NaN           0.366798            1       True         31
# 30          LightGBM_r94_BAG_L1_FULL      -0.256749  -0.493940  root_mean_squared_error        0.009990            NaN   0.147131                 0.009990                     NaN           0.147131            1       True         59
# 31    NeuralNetTorch_r79_BAG_L2_FULL      -0.256847  -0.407169  root_mean_squared_error        1.671372            NaN  73.831237                 0.041888                     NaN           2.375384            2       True         74
# 32       NeuralNetFastAI_BAG_L1_FULL      -0.257870  -0.476993  root_mean_squared_error        0.022932            NaN   0.408041                 0.022932                     NaN           0.408041            1       True          8
# 33  NeuralNetFastAI_r102_BAG_L1_FULL      -0.259188  -0.479739  root_mean_squared_error        0.029065            NaN   2.119164                 0.029065                     NaN           2.119164            1       True         22
# 34         LightGBM_r130_BAG_L1_FULL      -0.259216  -0.496422  root_mean_squared_error        0.009973            NaN   0.127505                 0.009973                     NaN           0.127505            1       True         29
# 35          LightGBM_r96_BAG_L2_FULL      -0.260676  -0.434069  root_mean_squared_error        1.660988            NaN  71.937480                 0.031504                     NaN           0.481627            2       True         78
# 36    NeuralNetTorch_r14_BAG_L1_FULL      -0.260681  -0.477158  root_mean_squared_error        0.016955            NaN   0.883922                 0.016955                     NaN           0.883922            1       True         37
# 37      RandomForest_r34_BAG_L1_FULL      -0.261118  -0.503799  root_mean_squared_error        0.056920       0.061829   0.354497                 0.056920                0.061829           0.354497            1       True         58
# 38   NeuralNetFastAI_r11_BAG_L1_FULL      -0.261133  -0.484765  root_mean_squared_error        0.036901            NaN   1.130241                 0.036901                     NaN           1.130241            1       True         32
# 39         CatBoost_r128_BAG_L1_FULL      -0.264576  -0.450357  root_mean_squared_error        0.011976            NaN   1.492634                 0.011976                     NaN           1.492634            1       True         61
# 40  NeuralNetFastAI_r103_BAG_L1_FULL      -0.265456  -0.478155  root_mean_squared_error        0.025931            NaN   0.621793                 0.025931                     NaN           0.621793            1       True         36
# 41              CatBoost_BAG_L1_FULL      -0.266330  -0.455340  root_mean_squared_error        0.013963            NaN   0.852878                 0.013963                     NaN           0.852878            1       True          6
# 42          CatBoost_r86_BAG_L1_FULL      -0.266698  -0.461028  root_mean_squared_error        0.009989            NaN   1.376496                 0.009989                     NaN           1.376496            1       True         50
# 43  NeuralNetFastAI_r145_BAG_L1_FULL      -0.267145  -0.477889  root_mean_squared_error        0.025930            NaN   0.442866                 0.025930                     NaN           0.442866            1       True         26
# 44          WeightedEnsemble_L2_FULL      -0.267604  -0.432929  root_mean_squared_error        0.203883            NaN  10.033784                 0.007999                     NaN           0.031932            2       True         63
# 45       RandomForestMSE_BAG_L2_FULL      -0.267693  -0.457665  root_mean_squared_error        1.702289            NaN  73.139922                 0.072805                0.071804           1.684070            2       True         66
# 46         CatBoost_r177_BAG_L1_FULL      -0.268909  -0.452543  root_mean_squared_error        0.009973            NaN   0.404720                 0.009973                     NaN           0.404720            1       True         12
# 47   NeuralNetTorch_r143_BAG_L1_FULL      -0.269559  -0.477025  root_mean_squared_error        0.015989            NaN   5.237231                 0.015989                     NaN           5.237231            1       True         60
# 48          CatBoost_r13_BAG_L1_FULL      -0.270811  -0.457201  root_mean_squared_error        0.014960            NaN   4.560522                 0.014960                     NaN           4.560522            1       True         23
# 49               XGBoost_BAG_L1_FULL      -0.271115  -0.470029  root_mean_squared_error        0.028923            NaN   0.042886                 0.028923                     NaN           0.042886            1       True          9
# 50    NeuralNetTorch_r22_BAG_L1_FULL      -0.271898  -0.479998  root_mean_squared_error        0.023936            NaN   2.667870                 0.023936                     NaN           2.667870            1       True         18
# 51    NeuralNetTorch_r79_BAG_L1_FULL      -0.273270  -0.470348  root_mean_squared_error        0.020944            NaN   4.054550                 0.020944                     NaN           4.054550            1       True         13
# 52         CatBoost_r137_BAG_L2_FULL      -0.275115  -0.443111  root_mean_squared_error        1.649430            NaN  71.829019                 0.019947                     NaN           0.373166            2       True         82
# 53    NeuralNetTorch_r41_BAG_L1_FULL      -0.277190  -0.466937  root_mean_squared_error        0.015957            NaN   1.844816                 0.015957                     NaN           1.844816            1       True         46
# 54         LightGBM_r161_BAG_L1_FULL      -0.279043  -0.462596  root_mean_squared_error        0.046875            NaN   0.986929                 0.046875                     NaN           0.986929            1       True         38
# 55         CatBoost_r167_BAG_L1_FULL      -0.279523  -0.456919  root_mean_squared_error        0.009974            NaN   0.771921                 0.009974                     NaN           0.771921            1       True         44
# 56          CatBoost_r69_BAG_L1_FULL      -0.279556  -0.451974  root_mean_squared_error        0.010971            NaN   0.554364                 0.010971                     NaN           0.554364            1       True         35
# 57          CatBoost_r70_BAG_L1_FULL      -0.279620  -0.443938  root_mean_squared_error        0.010971            NaN   0.481841                 0.010971                     NaN           0.481841            1       True         40
# 58  NeuralNetFastAI_r143_BAG_L1_FULL      -0.281758  -0.488950  root_mean_squared_error        0.029920            NaN   1.671422                 0.029920                     NaN           1.671422            1       True         39
# 59   NeuralNetTorch_r158_BAG_L1_FULL      -0.283137  -0.474972  root_mean_squared_error        0.018979            NaN   4.602356                 0.018979                     NaN           4.602356            1       True         49
# 60         CatBoost_r137_BAG_L1_FULL      -0.283545  -0.453930  root_mean_squared_error        0.010970            NaN   0.502090                 0.010970                     NaN           0.502090            1       True         21
# 61           XGBoost_r89_BAG_L1_FULL      -0.285665  -0.462646  root_mean_squared_error        0.019947            NaN   0.066805                 0.019947                     NaN           0.066805            1       True         27
# 62  NeuralNetFastAI_r134_BAG_L1_FULL      -0.289704  -0.475827  root_mean_squared_error        0.030970            NaN   4.492680                 0.030970                     NaN           4.492680            1       True         57
# 63          CatBoost_r49_BAG_L1_FULL      -0.291704  -0.449678  root_mean_squared_error        0.010988            NaN   0.698200                 0.010988                     NaN           0.698200            1       True         53
# 64            LightGBMXT_BAG_L2_FULL      -0.296385  -0.428292  root_mean_squared_error        1.649451            NaN  71.717033                 0.019968                     NaN           0.261181            2       True         64
# 65  NeuralNetFastAI_r111_BAG_L1_FULL      -0.298362  -0.502019  root_mean_squared_error        0.029947            NaN   1.280520                 0.029947                     NaN           1.280520            1       True         62
# 66   NeuralNetFastAI_r37_BAG_L1_FULL      -0.304623  -0.493215  root_mean_squared_error        0.026961            NaN   0.194922                 0.026961                     NaN           0.194922            1       True         51
# 67    NeuralNetTorch_r22_BAG_L2_FULL      -0.305354  -0.414153  root_mean_squared_error        1.670927            NaN  74.239662                 0.041444                     NaN           2.783810            2       True         79
# 68        NeuralNetTorch_BAG_L2_FULL      -0.307276  -0.424354  root_mean_squared_error        1.667417            NaN  74.280988                 0.037934                     NaN           2.825135            2       True         71
# 69              LightGBM_BAG_L2_FULL      -0.309593  -0.435128  root_mean_squared_error        1.648442            NaN  71.659770                 0.018959                     NaN           0.203918            2       True         65
# 70        KNeighborsUnif_BAG_L1_FULL      -0.313567  -0.549642  root_mean_squared_error        0.027078       0.019064   0.003871                 0.027078                0.019064           0.003871            1       True          1
# 71         LightGBM_r131_BAG_L2_FULL      -0.320052  -0.437660  root_mean_squared_error        1.651424            NaN  71.903941                 0.021941                     NaN           0.448088            2       True         75
# 72         LightGBMLarge_BAG_L2_FULL      -0.323222  -0.443960  root_mean_squared_error        1.649430            NaN  71.997607                 0.019946                     NaN           0.541754            2       True         72
# 73    NeuralNetTorch_r30_BAG_L1_FULL      -0.340182  -0.465130  root_mean_squared_error        0.032323            NaN   7.199017                 0.032323                     NaN           7.199017            1       True         28
# 74        KNeighborsDist_BAG_L1_FULL      -0.358505  -0.564002  root_mean_squared_error        0.023185       0.016477   0.002992                 0.023185                0.016477           0.002992            1       True          2
# 75   NeuralNetFastAI_r95_BAG_L1_FULL      -0.369815  -0.474063  root_mean_squared_error        0.024933            NaN   0.594599                 0.024933                     NaN           0.594599            1       True         45
# 76          WeightedEnsemble_L3_FULL      -0.372994  -0.371770  root_mean_squared_error        1.774089            NaN  76.404140                 0.007978                     NaN           0.020943            3       True         85
# 77       NeuralNetFastAI_BAG_L2_FULL      -0.387632  -0.399042  root_mean_squared_error        1.655834            NaN  71.795431                 0.026350                     NaN           0.339578            2       True         69
# 78           XGBoost_r33_BAG_L2_FULL      -0.410569  -0.457183  root_mean_squared_error        1.661071            NaN  72.609305                 0.031588                     NaN           1.153453            2       True         80
# 79  NeuralNetFastAI_r102_BAG_L2_FULL      -0.410755  -0.397939  root_mean_squared_error        1.664390            NaN  73.475637                 0.034906                     NaN           2.019785            2       True         83
# 80          LightGBM_r15_BAG_L1_FULL      -0.411708  -0.465978  root_mean_squared_error        0.012519            NaN   0.177395                 0.012519                     NaN           0.177395            1       True         48
# 81  NeuralNetFastAI_r191_BAG_L1_FULL      -0.434848  -0.470114  root_mean_squared_error        0.030918            NaN   0.373787                 0.030918                     NaN           0.373787            1       True         15
# 82               XGBoost_BAG_L2_FULL      -0.452304  -0.438702  root_mean_squared_error        1.654901            NaN  71.517688                 0.025418                     NaN           0.061835            2       True         70
# 83  NeuralNetFastAI_r191_BAG_L2_FULL      -0.480264  -0.387966  root_mean_squared_error        1.663898            NaN  71.926193                 0.034415                     NaN           0.470340            2       True         76
# 84         LightGBMLarge_BAG_L1_FULL      -0.480432  -0.456900  root_mean_squared_error        0.035904            NaN   0.836024                 0.035904                     NaN           0.836024            1       True         11
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	1005s	 = DyStack   runtime |	2595s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 2595s
# AutoGluon will save models to "AutogluonModels\ag-20241018_061124"
# Train Data Rows:    837
# Train Data Columns: 11
# Label Column:       present change
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    19095.64 MB
# 	Train Data (Original)  Memory Usage: 0.07 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 11 | ['CPI_yoy', 'CPI_mom', 'coreCPI', 'coreCPI_yoy', 'coreCPI_mom', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 11 | ['CPI_yoy', 'CPI_mom', 'coreCPI', 'coreCPI_yoy', 'coreCPI_mom', ...]
# 	0.0s = Fit runtime
# 	11 features in original data used to generate 11 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.07 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2595.1s of the 2595.09s of remaining time.
# 	-0.5312	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2595.05s of the 2595.05s of remaining time.
# 	-0.5459	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2595.01s of the 2595.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4596	 = Validation score   (-root_mean_squared_error)
# 	3.51s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2588.35s of the 2588.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4537	 = Validation score   (-root_mean_squared_error)
# 	2.16s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2583.26s of the 2583.25s of remaining time.
# 	-0.4587	 = Validation score   (-root_mean_squared_error)
# 	0.39s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2582.76s of the 2582.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	-0.4265	 = Validation score   (-root_mean_squared_error)
# 	22.71s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2557.33s of the 2557.32s of remaining time.
# 	-0.4584	 = Validation score   (-root_mean_squared_error)
# 	0.34s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2556.88s of the 2556.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4476	 = Validation score   (-root_mean_squared_error)
# 	3.86s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2550.18s of the 2550.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	-0.4264	 = Validation score   (-root_mean_squared_error)
# 	1.69s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2545.15s of the 2545.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.457	 = Validation score   (-root_mean_squared_error)
# 	9.44s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2532.82s of the 2532.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	-0.4471	 = Validation score   (-root_mean_squared_error)
# 	3.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2526.78s of the 2526.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	-0.431	 = Validation score   (-root_mean_squared_error)
# 	8.16s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2515.82s of the 2515.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4479	 = Validation score   (-root_mean_squared_error)
# 	12.08s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2500.89s of the 2500.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	-0.4633	 = Validation score   (-root_mean_squared_error)
# 	5.36s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2492.02s of the 2492.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4342	 = Validation score   (-root_mean_squared_error)
# 	5.51s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2483.68s of the 2483.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# 	-0.4172	 = Validation score   (-root_mean_squared_error)
# 	19.74s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 2460.94s of the 2460.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4735	 = Validation score   (-root_mean_squared_error)
# 	3.81s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 2454.15s of the 2454.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4587	 = Validation score   (-root_mean_squared_error)
# 	9.74s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 2441.68s of the 2441.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# 	-0.4178	 = Validation score   (-root_mean_squared_error)
# 	4.57s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 2434.25s of the 2434.25s of remaining time.
# 	-0.4542	 = Validation score   (-root_mean_squared_error)
# 	0.35s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 2433.79s of the 2433.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4289	 = Validation score   (-root_mean_squared_error)
# 	10.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 2420.71s of the 2420.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4462	 = Validation score   (-root_mean_squared_error)
# 	8.18s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 2409.71s of the 2409.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	-0.4302	 = Validation score   (-root_mean_squared_error)
# 	65.86s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 2340.83s of the 2340.83s of remaining time.
# 	-0.4458	 = Validation score   (-root_mean_squared_error)
# 	0.49s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 2340.22s of the 2340.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	-0.4484	 = Validation score   (-root_mean_squared_error)
# 	4.55s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 2332.44s of the 2332.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4344	 = Validation score   (-root_mean_squared_error)
# 	5.81s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 2323.84s of the 2323.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	-0.4267	 = Validation score   (-root_mean_squared_error)
# 	1.5s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 2319.37s of the 2319.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4237	 = Validation score   (-root_mean_squared_error)
# 	16.43s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 2300.18s of the 2300.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	-0.479	 = Validation score   (-root_mean_squared_error)
# 	0.63s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 2296.77s of the 2296.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.427	 = Validation score   (-root_mean_squared_error)
# 	11.54s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 2282.26s of the 2282.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4274	 = Validation score   (-root_mean_squared_error)
# 	3.99s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 2275.5s of the 2275.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4475	 = Validation score   (-root_mean_squared_error)
# 	6.18s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 2266.5s of the 2266.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	-0.4223	 = Validation score   (-root_mean_squared_error)
# 	1.34s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 2262.03s of the 2262.03s of remaining time.
# 	-0.4736	 = Validation score   (-root_mean_squared_error)
# 	0.43s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 2261.48s of the 2261.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4248	 = Validation score   (-root_mean_squared_error)
# 	5.19s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 2253.54s of the 2253.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4416	 = Validation score   (-root_mean_squared_error)
# 	4.17s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 2246.61s of the 2246.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4538	 = Validation score   (-root_mean_squared_error)
# 	6.23s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 2237.28s of the 2237.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	-0.4614	 = Validation score   (-root_mean_squared_error)
# 	1.82s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 2232.47s of the 2232.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4655	 = Validation score   (-root_mean_squared_error)
# 	12.98s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 2216.64s of the 2216.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	-0.4227	 = Validation score   (-root_mean_squared_error)
# 	11.29s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 2202.47s of the 2202.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4489	 = Validation score   (-root_mean_squared_error)
# 	12.54s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 2187.06s of the 2187.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	-0.4562	 = Validation score   (-root_mean_squared_error)
# 	5.69s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 2177.93s of the 2177.92s of remaining time.
# 	-0.4502	 = Validation score   (-root_mean_squared_error)
# 	0.47s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 2177.35s of the 2177.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	-0.4195	 = Validation score   (-root_mean_squared_error)
# 	19.71s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 2154.82s of the 2154.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.434	 = Validation score   (-root_mean_squared_error)
# 	5.18s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 2146.86s of the 2146.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4457	 = Validation score   (-root_mean_squared_error)
# 	8.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 2135.24s of the 2135.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	-0.4128	 = Validation score   (-root_mean_squared_error)
# 	9.11s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 2123.27s of the 2123.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4413	 = Validation score   (-root_mean_squared_error)
# 	5.22s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 2114.59s of the 2114.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4487	 = Validation score   (-root_mean_squared_error)
# 	10.98s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 2100.9s of the 2100.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	-0.4316	 = Validation score   (-root_mean_squared_error)
# 	91.03s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 2006.91s of the 2006.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4557	 = Validation score   (-root_mean_squared_error)
# 	4.13s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 2000.01s of the 2000.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4546	 = Validation score   (-root_mean_squared_error)
# 	5.16s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 1991.72s of the 1991.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4253	 = Validation score   (-root_mean_squared_error)
# 	5.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 1982.99s of the 1982.99s of remaining time.
# 	-0.4598	 = Validation score   (-root_mean_squared_error)
# 	0.41s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 1982.47s of the 1982.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.06%)
# 	-0.4717	 = Validation score   (-root_mean_squared_error)
# 	1.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 1978.61s of the 1978.6s of remaining time.
# 	-0.4817	 = Validation score   (-root_mean_squared_error)
# 	0.47s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 1978.03s of the 1978.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4456	 = Validation score   (-root_mean_squared_error)
# 	17.13s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 1958.12s of the 1958.11s of remaining time.
# 	-0.4821	 = Validation score   (-root_mean_squared_error)
# 	0.36s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 1957.67s of the 1957.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	-0.4693	 = Validation score   (-root_mean_squared_error)
# 	1.65s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 1953.22s of the 1953.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4571	 = Validation score   (-root_mean_squared_error)
# 	11.42s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 1939.01s of the 1939.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	-0.4159	 = Validation score   (-root_mean_squared_error)
# 	15.62s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 1920.6s of the 1920.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4528	 = Validation score   (-root_mean_squared_error)
# 	7.81s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 1909.86s of the 1909.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4568	 = Validation score   (-root_mean_squared_error)
# 	7.47s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 1899.12s of the 1899.12s of remaining time.
# 	-0.4827	 = Validation score   (-root_mean_squared_error)
# 	0.35s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 1898.67s of the 1898.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.18%)
# 	-0.4128	 = Validation score   (-root_mean_squared_error)
# 	3.39s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_r42_BAG_L1 ... Training model for up to 1499.15s of the 1499.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	-0.4616	 = Validation score   (-root_mean_squared_error)
# 	1.27s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 1495.04s of the 1495.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.4343	 = Validation score   (-root_mean_squared_error)
# 	17.66s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 1474.6s of the 1474.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.00%)
# 	-0.426	 = Validation score   (-root_mean_squared_error)
# 	13.76s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1457.57s of remaining time.
# 	Ensemble Weights: {'XGBoost_r34_BAG_L1': 0.364, 'CatBoost_r128_BAG_L1': 0.227, 'NeuralNetTorch_r30_BAG_L1': 0.182, 'NeuralNetFastAI_r138_BAG_L1': 0.091, 'NeuralNetFastAI_r191_BAG_L1': 0.045, 'NeuralNetFastAI_r100_BAG_L1': 0.045, 'NeuralNetTorch_r1_BAG_L1': 0.045}
# 	-0.4012	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1137.61s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 194.8 rows/s (105 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.39s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	1.29s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.34s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	0.54s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.07s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	3.69s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	0.6s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	3.95s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	0.43s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	0.71s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	1.67s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	0.33s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	1.9s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	0.33s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.35s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	0.57s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r102_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	1.54s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	4.81s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.49s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	0.42s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r145_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	7.09s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	4.41s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	0.31s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r11_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 19.
# 	1.28s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	0.03s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.43s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r69_BAG_L1_FULL ...
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r103_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.46s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r14_BAG_L1_FULL ...
# 	0.91s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r161_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r143_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	1.28s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r70_BAG_L1_FULL ...
# 	0.92s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r156_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	2.0s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r196_BAG_L1_FULL ...
# 	0.8s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.47s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r167_BAG_L1_FULL ...
# 	1.12s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r95_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.8s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r41_BAG_L1_FULL ...
# 	1.82s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r98_BAG_L1_FULL ...
# 	1.07s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r15_BAG_L1_FULL ...
# 	0.44s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r158_BAG_L1_FULL ...
# 	3.64s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r86_BAG_L1_FULL ...
# 	4.38s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r37_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.28s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r197_BAG_L1_FULL ...
# 	0.73s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r49_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.41s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r143_BAG_L1_FULL ...
# 	0.19s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.47s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r134_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	3.92s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.36s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r94_BAG_L1_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r143_BAG_L1_FULL ...
# 	2.57s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r128_BAG_L1_FULL ...
# 	1.69s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r111_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	2.17s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r31_BAG_L1_FULL ...
# 	1.35s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.35s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r65_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 17.
# 	2.34s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r88_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	1.9s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r30_BAG_L1_FULL ...
# 	0.57s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r49_BAG_L1_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r5_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r87_BAG_L1_FULL ...
# 	1.65s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r71_BAG_L1_FULL ...
# 	0.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r143_BAG_L1_FULL ...
# 	0.58s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.41s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.51s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r31_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r185_BAG_L1_FULL ...
# 	4.05s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r160_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.51s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r60_BAG_L1_FULL ...
# 	0.5s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.45s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r135_BAG_L1_FULL ...
# 	0.17s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r22_BAG_L1_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r69_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.48s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r6_BAG_L1_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r138_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	1.04s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r121_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r172_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	0.23s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r180_BAG_L1_FULL ...
# 	1.09s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r76_BAG_L1_FULL ...
# 	0.63s	 = Training   runtime
# Fitting model: ExtraTrees_r197_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.6s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r121_BAG_L1_FULL ...
# 	3.59s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r127_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	2.3s	 = Training   runtime
# Fitting model: RandomForest_r16_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.79s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r194_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.43s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r12_BAG_L1_FULL ...
# 	2.94s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r135_BAG_L1_FULL ...
# 	3.4s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r4_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	0.36s	 = Training   runtime
# Fitting model: ExtraTrees_r126_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.69s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r36_BAG_L1_FULL ...
# 	1.0s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r100_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	3.99s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r163_BAG_L1_FULL ...
# 	0.4s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r198_BAG_L1_FULL ...
# 	0.98s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r187_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	3.15s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r19_BAG_L1_FULL ...
# 	0.48s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r95_BAG_L1_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r34_BAG_L1_FULL ...
# 	0.36s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r42_BAG_L1_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r1_BAG_L1_FULL ...
# 	3.95s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r89_BAG_L1_FULL ...
# 	3.82s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'XGBoost_r34_BAG_L1': 0.364, 'CatBoost_r128_BAG_L1': 0.227, 'NeuralNetTorch_r30_BAG_L1': 0.182, 'NeuralNetFastAI_r138_BAG_L1': 0.091, 'NeuralNetFastAI_r191_BAG_L1': 0.045, 'NeuralNetFastAI_r100_BAG_L1': 0.045, 'NeuralNetTorch_r1_BAG_L1': 0.045}
# 	0.02s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "WeightedEnsemble_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 136.84s ... Best model: "WeightedEnsemble_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20241018_061124")

# %%
leaderboard=regressor.leaderboard(silent=True)

# %%
leaderboard.head(20)
# Out:
#                         model  score_val              eval_metric  \
# 0         WeightedEnsemble_L2  -0.401211  root_mean_squared_error
# 1          XGBoost_r34_BAG_L1  -0.412819  root_mean_squared_error
# 2          XGBoost_r98_BAG_L1  -0.412834  root_mean_squared_error
# 3        CatBoost_r128_BAG_L1  -0.415939  root_mean_squared_error
# 4          XGBoost_r95_BAG_L1  -0.417138  root_mean_squared_error
# 5          CatBoost_r9_BAG_L1  -0.417245  root_mean_squared_error
# 6          XGBoost_r33_BAG_L1  -0.417784  root_mean_squared_error
# 7        CatBoost_r180_BAG_L1  -0.417880  root_mean_squared_error
# 8          XGBoost_r22_BAG_L1  -0.418630  root_mean_squared_error
# 9          XGBoost_r49_BAG_L1  -0.419388  root_mean_squared_error
# 10       CatBoost_r167_BAG_L1  -0.419545  root_mean_squared_error
# 11        CatBoost_r60_BAG_L1  -0.420417  root_mean_squared_error
# 12        XGBoost_r194_BAG_L1  -0.422309  root_mean_squared_error
# 13       CatBoost_r163_BAG_L1  -0.422350  root_mean_squared_error
# 14        CatBoost_r70_BAG_L1  -0.422656  root_mean_squared_error
# 15  NeuralNetTorch_r30_BAG_L1  -0.423713  root_mean_squared_error
# 16        CatBoost_r69_BAG_L1  -0.424798  root_mean_squared_error
# 17        CatBoost_r49_BAG_L1  -0.425310  root_mean_squared_error
# 18        CatBoost_r12_BAG_L1  -0.425697  root_mean_squared_error
# 19       CatBoost_r198_BAG_L1  -0.425793  root_mean_squared_error
#
#     pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0        0.539135  83.742895                0.000000           0.022546
# 1        0.034900   3.393745                0.034900           3.393745
# 2        0.043945   9.105457                0.043945           9.105457
# 3        0.018950  15.617385                0.018950          15.617385
# 4        0.020945   1.492482                0.020945           1.492482
# 5        0.018265  19.744932                0.018265          19.744932
# 6        0.030837   4.574801                0.030837           4.574801
# 7        0.015516  10.388194                0.015516          10.388194
# 8        0.023939   1.371989                0.023939           1.371989
# 9        0.026951   2.590258                0.026951           2.590258
# 10       0.014933  19.714101                0.014933          19.714101
# 11       0.014926   9.411555                0.014926           9.411555
# 12       0.022590   1.335561                0.022590           1.335561
# 13       0.013969   5.578962                0.013969           5.578962
# 14       0.014940  11.287488                0.014940          11.287488
# 15       0.071421  16.429492                0.071421          16.429492
# 16       0.010966   5.187224                0.010966           5.187224
# 17       0.009974   5.756073                0.009974           5.756073
# 18       0.015956  49.557791                0.015956          49.557791
# 19       0.014920  16.628330                0.014920          16.628330
#
#     stack_level  can_infer  fit_order
# 0             2       True        109
# 1             1       True        105
# 2             1       True         47
# 3             1       True         61
# 4             1       True        104
# 5             1       True         16
# 6             1       True         19
# 7             1       True         87
# 8             1       True         81
# 9             1       True         68
# 10            1       True         44
# 11            1       True         78
# 12            1       True         33
# 13            1       True        100
# 14            1       True         40
# 15            1       True         28
# 16            1       True         35
# 17            1       True         53
# 18            1       True         94
# 19            1       True        101

# %%
feature_importance = regressor.feature_importance(df)
feature_importance
# Out:
# Computing feature importance via permutation shuffling for 11 features using 837 rows with 5 shuffle sets...
# 	10.87s	= Expected runtime (2.17s per shuffle set)
# 	5.08s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                importance    stddev       p_value  n  p99_high   p99_low
# interest rate    0.150238  0.007701  8.256509e-07  5  0.166095  0.134381
# PCE_yoy          0.111597  0.005622  7.703431e-07  5  0.123173  0.100021
# coreCPI_yoy      0.100942  0.002010  1.884875e-08  5  0.105080  0.096804
# CPI_yoy          0.082154  0.002837  1.704734e-07  5  0.087996  0.076312
# corePCE_yoy      0.074394  0.004130  1.134795e-06  5  0.082897  0.065891
# corePCE_mom      0.067258  0.009347  4.363319e-05  5  0.086504  0.048012
# PPI_yoy          0.052886  0.005740  1.639705e-05  5  0.064706  0.041067
# coreCPI_mom      0.052485  0.001615  1.075462e-07  5  0.055811  0.049159
# CPI_mom          0.049312  0.005515  1.846926e-05  5  0.060668  0.037956
# coreCPI          0.037006  0.001833  7.200728e-07  5  0.040780  0.033232
# PCE              0.031562  0.001651  8.954880e-07  5  0.034962  0.028162

# %%
infer_df = pd.read_csv('dataframes/infer_df.csv')
infer_df = infer_df.loc[:, (infer_df.columns != 'date') & (infer_df.columns != 'previous interest rate') & (infer_df.columns != 'next interest rate') & (infer_df.columns != 'previous change')
                  & (infer_df.columns != 'CPI')& (infer_df.columns != 'corePCE')& (infer_df.columns != 'PPI')& (infer_df.columns != 'industrial production')]
infer_dataset = TabularDataset(infer_df)
inference = regressor.predict(infer_dataset)
inference
# Out:
# 0   -0.122593
# Name: present change, dtype: float32
